# %%
import os
import cv2 as cv
import matplotlib.pyplot as plt
import tensorflow as tf
from mtcnn.mtcnn import MTCNN

# %%
path = 'D:\ETE\Data\Data_MIT/00251/frames/'
img = cv.cvtColor(cv.imread(path + '00002.jpg'), cv.COLOR_BGR2RGB)
plt.imshow(img);

# %%
# face detection with mtcnn on a photograph
from matplotlib import pyplot
from matplotlib.patches import Rectangle
from mtcnn.mtcnn import MTCNN

# draw an image with detected objects
def draw_image_with_boxes(filename, result_list):
    # load the image
    # data = pyplot.imread(filename)
    data = cv.cvtColor(cv.imread(filename), cv.COLOR_BGR2RGB)
    # plot the image
    pyplot.figure(dpi=250)
    pyplot.imshow(data)  
    # get the context for drawing boxes
    ax = pyplot.gca()
    # plot each box

    for result in result_list:
        # get coordinates
        x, y, width, height = result['box']
        # create the shape
        rect = Rectangle((x, y), width, height, fill=False, color='red')
        # draw the box
        ax.add_patch(rect)
        # show the plot
    pyplot.show()

filename = path + '00002.jpg'
# load image from file
# pixels = pyplot.imread(filename)
pixels = cv.cvtColor(cv.imread(filename), cv.COLOR_BGR2RGB)
# create the detector, using default weights
detector = MTCNN()
# detect faces in the image
faces = detector.detect_faces(pixels)
draw_image_with_boxes(filename, faces)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-5b84aebb4d1a> in <module>
#      31 pixels = cv.cvtColor(cv.imread(filename), cv.COLOR_BGR2RGB)
#      32 # create the detector, using default weights
# ---> 33 detector = MTCNN()
#      34 # detect faces in the image
#      35 faces = detector.detect_faces(pixels)
#
# ~\Anaconda3\envs\tf-gpu\lib\site-packages\mtcnn\mtcnn.py in __init__(self, weights_file, min_face_size, steps_threshold, scale_factor)
#      86         self._scale_factor = scale_factor
#      87
# ---> 88         self._pnet, self._rnet, self._onet = NetworkFactory().build_P_R_O_nets_from_file(weights_file)
#      89
#      90
#
# ~\Anaconda3\envs\tf-gpu\lib\site-packages\mtcnn\network\factory.py in build_P_R_O_nets_from_file(self, weights_file)
#     121         weights = np.load(weights_file, allow_pickle=True).tolist()
#     122
# ...

# %%
detector = MTCNN()
detector.detect_faces(img)
